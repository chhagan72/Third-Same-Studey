# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # statistical graphics

# %%
df = pd.read_csv("Q9_a.csv")
df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
df.mean(numeric_only=True)
# Out:
# Index    25.50
# speed    15.40
# dist     42.98
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Index    25.5
# speed    15.0
# dist     36.0
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#     Index  speed  dist
# 0       1   20.0  26.0
# 1       2    NaN   NaN
# 2       3    NaN   NaN
# 3       4    NaN   NaN
# 4       5    NaN   NaN
# 5       6    NaN   NaN
# 6       7    NaN   NaN
# 7       8    NaN   NaN
# 8       9    NaN   NaN
# 9      10    NaN   NaN
# 10     11    NaN   NaN
# 11     12    NaN   NaN
# 12     13    NaN   NaN
# 13     14    NaN   NaN
# 14     15    NaN   NaN
# 15     16    NaN   NaN
# 16     17    NaN   NaN
# 17     18    NaN   NaN
# 18     19    NaN   NaN
# 19     20    NaN   NaN
# 20     21    NaN   NaN
# 21     22    NaN   NaN
# 22     23    NaN   NaN
# 23     24    NaN   NaN
# 24     25    NaN   NaN
# 25     26    NaN   NaN
# 26     27    NaN   NaN
# 27     28    NaN   NaN
# 28     29    NaN   NaN
# 29     30    NaN   NaN
# 30     31    NaN   NaN
# 31     32    NaN   NaN
# 32     33    NaN   NaN
# 33     34    NaN   NaN
# 34     35    NaN   NaN
# 35     36    NaN   NaN
# 36     37    NaN   NaN
# 37     38    NaN   NaN
# 38     39    NaN   NaN
# ...

# %%
df.describe()
# Out:
#           Index      speed        dist
# count  50.00000  50.000000   50.000000
# mean   25.50000  15.400000   42.980000
# std    14.57738   5.287644   25.769377
# min     1.00000   4.000000    2.000000
# 25%    13.25000  12.000000   26.000000
# 50%    25.50000  15.000000   36.000000
# 75%    37.75000  19.000000   56.000000
# max    50.00000  25.000000  120.000000

# %%
# measures asymmetric - curve is either rightmost or leftmost ->> ranges from  -infinity to + infinity
# index is perfectly symmetric
df.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
# it measures flatness of curve kurtosis or kurt ->> ranges from  -infinity to + infinity
# index goes minus means flat
df.kurtosis()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
sns.boxplot(df.speed)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='speed'>
